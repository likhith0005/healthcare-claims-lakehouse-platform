# %%
print("=" * 50)
print("HEALTHCARE DATASETS")
print("=" * 50)

datasets = [
    ("claims_cleaned", "Silver healthcare claims"),
    ("claims_dashboard", "Dashboard aggregated dataset"),
    ("real_ml_fraud_predictions", "ML prediction dataset"),
    ("data_quality_metrics", "Validation metrics"),
    ("rejected_claims_records", "Rejected bad records")
]

datasets_df = spark.createDataFrame(
    datasets,
    ["table_name", "description"]
)

display(datasets_df)
# Out:
# ...
# HEALTHCARE DATASETS
# ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_name</th><th>description</th></tr></thead><tbody><tr><td>claims_cleaned</td><td>Silver healthcare claims</td></tr><tr><td>claims_dashboard</td><td>Dashboard aggregated dataset</td></tr><tr><td>real_ml_fraud_predictions</td><td>ML prediction dataset</td></tr><tr><td>data_quality_metrics</td><td>Validation metrics</td></tr><tr><td>rejected_claims_records</td><td>Rejected bad records</td></tr></tbody></table></div>
