# %%
displayHTML("""

<h1 style='color:#4CAF50'>
Healthcare Migration Accelerator Architecture
</h1>

<hr>

<h2>Pipeline Flow</h2>

<pre>

        SOURCE SYSTEMS
   ┌─────────────────────┐
   │ SQL Server          │
   │ Oracle              │
   │ CSV Files           │
   │ REST APIs           │
   └─────────┬───────────┘
             │
             ▼

      BRONZE INGESTION
   ┌─────────────────────┐
   │ Raw Data Load       │
   │ Incremental Load    │
   │ Multi-source Load   │
   └─────────┬───────────┘
             │
             ▼

    SILVER TRANSFORMATION
   ┌─────────────────────┐
   │ Data Cleansing      │
   │ Deduplication       │
   │ Validation Rules    │
   └─────────┬───────────┘
             │
             ▼

      GOLD AGGREGATION
   ┌─────────────────────┐
   │ KPI Metrics         │
   │ Claims Dashboard    │
   │ Reporting Tables    │
   └─────────┬───────────┘
             │
             ▼

      ADVANCED LAYERS
   ┌─────────────────────┐
   │ ML Fraud Detection  │
   │ NLP Analytics       │
   │ Streaming           │
   │ REST API            │
   │ Airflow DAG         │
   │ Terraform IaC       │
   └─────────┬───────────┘
             │
             ▼

      GOVERNANCE LAYER
   ┌─────────────────────┐
   │ Unity Catalog       │
   │ Audit Logs          │
   │ Data Quality        │
   │ Validation Metrics  │
   └─────────────────────┘

</pre>

<hr>

<h2>Technology Stack</h2>

<ul>
<li>Databricks</li>
<li>PySpark</li>
<li>Delta Lake</li>
<li>SQL</li>
<li>MLflow</li>
<li>Terraform</li>
<li>Airflow</li>
<li>REST APIs</li>
<li>Streaming Pipelines</li>
</ul>

""")
# Out:
# <h1 style='color:#4CAF50'>
# Healthcare Migration Accelerator Architecture
# </h1>
#
# <hr>
#
# <h2>Pipeline Flow</h2>
#
# <pre>
#
#         SOURCE SYSTEMS
#    ┌─────────────────────┐
#    │ SQL Server          │
#    │ Oracle              │
#    │ CSV Files           │
#    │ REST APIs           │
#    └─────────┬───────────┘
#              │
#              ▼
#
#       BRONZE INGESTION
#    ┌─────────────────────┐
#    │ Raw Data Load       │
#    │ Incremental Load    │
#    │ Multi-source Load   │
#    └─────────┬───────────┘
#              │
#              ▼
#
#     SILVER TRANSFORMATION
#    ┌─────────────────────┐
#    │ Data Cleansing      │
#    │ Deduplication       │
#    │ Validation Rules    │
#    └─────────┬───────────┘
#              │
#              ▼
#
#       GOLD AGGREGATION
#    ┌─────────────────────┐
#    │ KPI Metrics         │
#    │ Claims Dashboard    │
#    │ Reporting Tables    │
#    └─────────┬───────────┘
#              │
#              ▼
#
# ...
